# %% [markdown]
# # PyWavelets 使用指南
# 官方网址：https://pywavelets.readthedocs.io/en/latest/index.html

# %% [markdown]
# ## 安装（python）
# pip install PyWavelets
#
# conda install pywavelets

# %%
"""
连续小波变换（CWT）:
   pywt.cwt(data, scales, wavelet, sampling_period, method, axis, precision)
        输入：
            - data:数据
            - scales:尺度列表
            - wavelet:小波母函数 ['morl'、'cmorB-C'、'mexh'、'gausP'、'shanB-C'等]
            - sampling_period:采样间隔 [sampling_period = 1.0 / fs]
            - method:方法 ['conv','fft']
            - axis:轴 [指定对哪一维做变换（适用于多维数组）]
            - precision:数值精度
        输出：
            - coefs: 小波系数 [是信号在不同尺度和时间点上与小波母函数的相似度]
            - frequencies: 对应的中心频率（Hz）
-------------------------------------------------------------------------------------------------------
离散小波变换（DWT）:
    pywt.dwt(data, wavelet, mode, axis=-1) 
    pywt.wavedec(data, wavelet, mode='symmetric', level=None, axis=-1) 
        输入：
            - data:输入信号
            - wavelet:小波基函数名称['haar','dbN','symN','coifN','biorNr.Nd']
            - mode:边界延拓方式（如何处理信号边缘）['zero','constant','symmetric','reflect']
            - axis:指定对哪一维进行变换
            - wavelet:分解层级（必须是>= 0）
        输出：
            - (cA,cD)近似系数(父函数-和)和细节系数(母函数-差)
            - [cA_n，cD_n，cD_n-1，......，cD2，cD1]
"""
